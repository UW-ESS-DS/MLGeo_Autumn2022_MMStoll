# %% [markdown]
# # ESS 569 Practice Notebook
# Mary Margaret Stoll
# <br> 9/30/22

# %%
#Import all useful modules
import numpy as np
import matplotlib.pyplot as plt

# %%
#Declare parameters
P = np.pi
x = np.arange(15) #this will make an array that is 15 elements, starts at 0

# %%
plot_1 = plt.plot(x)
plt.xlabel('x axis')
plt.ylabel('$\pi$ y axis')
plt.grid()
plt.savefig('toto.png')
